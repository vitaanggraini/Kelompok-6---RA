# %% [markdown]
# Nomor 1

# %%
def f(x):
  return 4*x

def g(x):
  return x*x

def h(x):
  return 3+x

#composition
h(g(f(4)))
# Out:
# 259

# %%
def compose(f1, f2):
  return lambda v: f1(f2(v))

hgf = compose(h, compose(g,f))
hgf(3)
# Out:
# 147

# %% [markdown]
# Nomor 5 Metode Bisection

# %%
def bisection_method(f, x0, x1, tol):
    while True:
        x2 = (x0 + x1) / 2
        f_x0 = f(x0)
        f_x2 = f(x2)

        if abs(f_x2) < tol:
            return x2

        if f_x0 * f_x2 < 0:
            x1 = x2
        elif f_x0 * f_x2 > 0:
            x0 = x2
        else:
            return x2

# Fungsi yang diberikan: f(x) = x - 2^x
f = lambda x: x - 2**x

# Initial guesses
initial_guess_x0 = 0.1
initial_guess_x1 = 0.9

# Tolerance
tolerance = 1e-5

# Menjalankan metode bisection
root = bisection_method(f, initial_guess_x0, initial_guess_x1, tolerance)
print("Root found:", root)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-137271d18b5d> in <cell line: 28>()
#      26
#      27 # Menjalankan metode bisection
# ---> 28 root = bisection_method(f, initial_guess_x0, initial_guess_x1, tolerance)
#      29 print("Root found:", root)
#
# <ipython-input-1-137271d18b5d> in bisection_method(f, x0, x1, tol)
#       1 def bisection_method(f, x0, x1, tol):
# ----> 2     while True:
#       3         x2 = (x0 + x1) / 2
#       4         f_x0 = f(x0)
#       5         f_x2 = f(x2)
#
# KeyboardInterrupt:

# %%
def bisection_method(f, x0, x1, tol, max_iter=1000):
    iter_count = 0
    while iter_count < max_iter:
        x2 = (x0 + x1) / 2
        f_x0 = f(x0)
        f_x2 = f(x2)

        if abs(f_x2) < tol:
            return x2

        if f_x0 * f_x2 < 0:
            x1 = x2
        elif f_x0 * f_x2 > 0:
            x0 = x2
        else:
            return x2

        iter_count += 1

    raise RuntimeError("Bisection method did not converge within the maximum number of iterations.")

# Fungsi yang diberikan: f(x) = x - 2^x
f = lambda x: x - 2**x

# Initial guesses
initial_guess_x0 = 0.1
initial_guess_x1 = 0.9

# Tolerance
tolerance = 1e-5

# Menjalankan metode bisection
try:
    root = bisection_method(f, initial_guess_x0, initial_guess_x1, tolerance)
    print("Root found:", root)
except RuntimeError as e:
    print(e)
# Out:
# Bisection method did not converge within the maximum number of iterations.
